# %% [markdown]
# # Using the Sagemaker SDK with built-in algoriths ( page - 118 )

# %% [markdown]
# ## 1. Preparing Data

# %%
import pandas as pd

# %%
# !ls -ltr
# Out:
# total 792
# drwxr-xr-x 2 root root   6144 Jan 15  2020 bank-additional
# -rw-r--r-- 1 root root 432828 Jan 15  2020 bank-additional.zip
# drwxr-xr-x 2 root root   6144 Apr  4 23:18 xai
# -rw-r--r-- 1 root root 271549 Apr  4 23:23 Model-Metrics-Parameters.png
# -rw-r--r-- 1 root root   2053 Apr  4 23:24 Notes.txt
# -rw-r--r-- 1 root root  22541 Apr  5 01:19 AutoPilot.ipynb
# drwxr-xr-x 3 root root   6144 Apr  5 01:25 output-artifacts
# -rw-r--r-- 1 root root     58 Apr  5 01:28 README.md
# -rw-r--r-- 1 root root  18968 Apr  5 08:44 SageMakerSDK-BuiltIn-Algorithms.ipynb
# -rw-r--r-- 1 root root  35101 Apr  5 08:45 housing.csv

# %%
dataset = pd.read_csv('housing.csv')

# %%
print(dataset.shape)
# Out:
# (506, 13)

# %%
dataset[:5]
# Out:
#       crim    zn  indus  chas    nox    age    rm     dis  rad    tax  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    ptratio  lstat  medv
# 0     15.3   4.98  24.0
# 1     17.8   9.14  21.6
# 2     17.8   4.03  34.7
# 3     18.7   2.94  33.4
# 4     18.7   5.33  36.2

# %% [markdown]
#    - 12 features, output: medv
#
# Reading the algorithm documentation (https://docs.aws.amazon.com/sagemaker/latest/dg/cdf-training.html), we see that Amazon SageMaker requires that a CSV file doesn't have a header record and that the target variable is in the first column. Accordingly, we move the medv column to the front of the dataframe:

# %%
dataset = pd.concat([dataset['medv'], dataset.drop(['medv'], axis=1)], axis=1)

# %%
dataset[:5]
# Out:
#    medv     crim    zn  indus  chas    nox    age    rm     dis  rad    tax  \
# 0  24.0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  21.6  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  34.7  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  33.4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  36.2  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    ptratio  lstat
# 0     15.3   4.98
# 1     17.8   9.14
# 2     17.8   4.03
# 3     18.7   2.94
# 4     18.7   5.33

# %%
from sklearn.model_selection import train_test_split

# %%
training_dataset, validation_dataset = train_test_split(dataset, test_size=0.1)

# %%
training_dataset.to_csv('training_dataset.csv', index=False, header=False)
validation_dataset.to_csv('validation_dataset.csv', index=False, header=False)

# %%
import sagemaker

# %%
sess = sagemaker.Session()

# %%
bucket = sess.default_bucket()

# %%
bucket
# Out:
# 'sagemaker-us-west-2-076084266064'

# %%
prefix='boston-housing'

# %%
training_data_path = sess.upload_data(path='training_dataset.csv', key_prefix=prefix + '/input/training')

# %%
validation_data_path = sess.upload_data(path='validation_dataset.csv', key_prefix=prefix + '/input/validation')

# %%
print(training_data_path)
# Out:
# s3://sagemaker-us-west-2-076084266064/boston-housing/input/training/training_dataset.csv

# %%
print(validation_data_path)
# Out:
# s3://sagemaker-us-west-2-076084266064/boston-housing/input/validation/validation_dataset.csv

# %% [markdown]
# ## Configuring a training job

# %%
import boto3
from sagemaker import image_uris

# %%
region = boto3.Session().region_name
container = image_uris.retrieve('linear-learner', region)

# %%
container
# Out:
# '174872318107.dkr.ecr.us-west-2.amazonaws.com/linear-learner:1'

# %%
## configure the training job 
from sagemaker.estimator import Estimator

# %%
ll_estimator = Estimator(
    container, 
    role=sagemaker.get_execution_role(),
    instance_count=1,
    instance_type='ml.m5.large',
    output_path='s3://{}/{}/output'.format(bucket,prefix)
)
# Out:
# Couldn't call 'get_role' to get Role ARN from role name AmazonSageMaker-ExecutionRole-20210403T113990 to get Role path.
# Assuming role was created in SageMaker AWS console, as the name contains `AmazonSageMaker-ExecutionRole`. Defaulting to Role ARN with service-role in path. If this Role ARN is incorrect, please add IAM read permissions to your role or supply the Role Arn directly.

# %%
sagemaker.get_execution_role()
# Out:
# Couldn't call 'get_role' to get Role ARN from role name AmazonSageMaker-ExecutionRole-20210403T113990 to get Role path.
# Assuming role was created in SageMaker AWS console, as the name contains `AmazonSageMaker-ExecutionRole`. Defaulting to Role ARN with service-role in path. If this Role ARN is incorrect, please add IAM read permissions to your role or supply the Role Arn directly.
# 'arn:aws:iam::076084266064:role/service-role/AmazonSageMaker-ExecutionRole-20210403T113990'

# %%
ll_estimator

# %%
ll_estimator.set_hyperparameters(
    predictor_type='regressor',
    mini_batch_size=32)

# %%
training_data_channel = sagemaker.TrainingInput(
    s3_data=training_data_path, content_type='text/csv')

# %%
validation_data_channel = sagemaker.TrainingInput(
    s3_data=validation_data_path, content_type='text/csv'
)

# %% [markdown]
# ## Launching a training job

# %%
ll_estimator.fit({'train': training_data_channel, 
                 'validation': validation_data_channel})
# Out:
# 2021-04-05 09:08:40 Starting - Starting the training job...
# 2021-04-05 09:09:03 Starting - Launching requested ML instancesProfilerReport-1617613720: InProgress
# ......
# 2021-04-05 09:10:07 Starting - Preparing the instances for training......
# 2021-04-05 09:11:04 Downloading - Downloading input data...
# 2021-04-05 09:11:27 Training - Downloading the training image.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/05/2021 09:11:46 INFO 140498629949248] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [04/05/2021 09:11:46 INFO 140498629949248] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'predictor_type': 'regressor', 'mini_batch_size': '32'}
# [04/05/2021 09:11:46 INFO 140498629949248] Final configuration: {'mini_batch_size': '32', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [04/05/2021 09:11:46 WARNING 140498629949248] Loggers have already been setup.
# Process 1 is a worker.
# [04/05/2021 09:11:46 INFO 140498629949248] Using default worker.
# [04/05/2021 09:11:46 INFO 140498629949248] Checkpoint loading and saving are disabled.
# [04/05/2021 09:11:46 INFO 140498629949248] Create Store: local
# [04/05/2021 09:11:46 INFO 140498629949248] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fc8051f4bd0>
# [04/05/2021 09:11:46 INFO 140498629949248] Scaling model computed with parameters:
#  {'stdev_label':
# [9.196797]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [8.88990116e+00 2.31020584e+01 6.72062492e+00 2.46052608e-01
#  1.12481765e-01 7.13041842e-01 2.80277729e+01 2.05780053e+00
#  8.73367310e+00 1.68403824e+02 2.16233468e+00 7.14776325e+00]
# <NDArray 12 @cpu(0)>, 'mean_label':
# [22.43661]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [3.7696650e+00 1.1166295e+01 1.1047412e+01 6.4732149e-02 5.5297458e-01
#  6.2822990e+00 6.8410271e+01 3.7763133e+00 9.6629467e+00 4.0943756e+02
#  1.8501114e+01 1.2709241e+01]
# <NDArray 12 @cpu(0)>}
# [04/05/2021 09:11:46 INFO 140498629949248] nvidia-smi: took 0.031 seconds to run.
# [04/05/2021 09:11:46 INFO 140498629949248] nvidia-smi identified 0 GPUs.
# [04/05/2021 09:11:46 INFO 140498629949248] Number of GPUs being used: 0
# #metrics {"StartTime": 1617613906.5321724, "EndTime": 1617613906.5322042, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 487.0, "count": 1, "min": 487, "max": 487}, "Total Batches Seen": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# #metrics {"StartTime": 1617613906.8509145, "EndTime": 1617613906.8509696, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.7377581532512393, "count": 1, "min": 0.7377581532512393, "max": 0.7377581532512393}}}
#
# #metrics {"StartTime": 1617613906.851051, "EndTime": 1617613906.851066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.825714253953525, "count": 1, "min": 0.825714253953525, "max": 0.825714253953525}}}
#
# #metrics {"StartTime": 1617613906.8511086, "EndTime": 1617613906.851118, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.872662039739745, "count": 1, "min": 0.872662039739745, "max": 0.872662039739745}}}
#
# #metrics {"StartTime": 1617613906.8511531, "EndTime": 1617613906.8511622, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.8704295882156917, "count": 1, "min": 0.8704295882156917, "max": 0.8704295882156917}}}
#
# #metrics {"StartTime": 1617613906.8511975, "EndTime": 1617613906.8512056, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.8076333105564117, "count": 1, "min": 0.8076333105564117, "max": 0.8076333105564117}}}
#
# #metrics {"StartTime": 1617613906.8515148, "EndTime": 1617613906.851536, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.9299405642918178, "count": 1, "min": 0.9299405642918178, "max": 0.9299405642918178}}}
#
# #metrics {"StartTime": 1617613906.8516765, "EndTime": 1617613906.8516958, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.7453513549906867, "count": 1, "min": 0.7453513549906867, "max": 0.7453513549906867}}}
#
# #metrics {"StartTime": 1617613906.8517451, "EndTime": 1617613906.8517566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.8220245433705193, "count": 1, "min": 0.8220245433705193, "max": 0.8220245433705193}}}
#
# #metrics {"StartTime": 1617613906.8517976, "EndTime": 1617613906.8518088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.7850554223571505, "count": 1, "min": 0.7850554223571505, "max": 0.7850554223571505}}}
#
# #metrics {"StartTime": 1617613906.8520372, "EndTime": 1617613906.8520553, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.6125576410974775, "count": 1, "min": 0.6125576410974775, "max": 0.6125576410974775}}}
#
# #metrics {"StartTime": 1617613906.852135, "EndTime": 1617613906.85215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.9747364542313984, "count": 1, "min": 0.9747364542313984, "max": 0.9747364542313984}}}
#
# #metrics {"StartTime": 1617613906.8521929, "EndTime": 1617613906.8522043, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.8692157098225185, "count": 1, "min": 0.8692157098225185, "max": 0.8692157098225185}}}
#
# #metrics {"StartTime": 1617613906.8522453, "EndTime": 1617613906.8522565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.898023743714605, "count": 1, "min": 0.898023743714605, "max": 0.898023743714605}}}
#
# #metrics {"StartTime": 1617613906.8522944, "EndTime": 1617613906.8523564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.7847935195480075, "count": 1, "min": 0.7847935195480075, "max": 0.7847935195480075}}}
#
# #metrics {"StartTime": 1617613906.8524437, "EndTime": 1617613906.852457, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.8090367381061826, "count": 1, "min": 0.8090367381061826, "max": 0.8090367381061826}}}
#
# #metrics {"StartTime": 1617613906.852496, "EndTime": 1617613906.8525066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.8727920821734837, "count": 1, "min": 0.8727920821734837, "max": 0.8727920821734837}}}
#
# #metrics {"StartTime": 1617613906.8525448, "EndTime": 1617613906.8525534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.7547885520117623, "count": 1, "min": 0.7547885520117623, "max": 0.7547885520117623}}}
#
# #metrics {"StartTime": 1617613906.8525913, "EndTime": 1617613906.8526013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.885888859629631, "count": 1, "min": 0.885888859629631, "max": 0.885888859629631}}}
#
# #metrics {"StartTime": 1617613906.8527493, "EndTime": 1617613906.8527632, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.6984504408070019, "count": 1, "min": 0.6984504408070019, "max": 0.6984504408070019}}}
#
# #metrics {"StartTime": 1617613906.8528063, "EndTime": 1617613906.8528192, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7807862056153161, "count": 1, "min": 0.7807862056153161, "max": 0.7807862056153161}}}
#
# #metrics {"StartTime": 1617613906.8528574, "EndTime": 1617613906.8528671, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.7557855354888099, "count": 1, "min": 0.7557855354888099, "max": 0.7557855354888099}}}
#
# #metrics {"StartTime": 1617613906.8529048, "EndTime": 1617613906.8529158, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.659684137574264, "count": 1, "min": 0.659684137574264, "max": 0.659684137574264}}}
#
# #metrics {"StartTime": 1617613906.8529515, "EndTime": 1617613906.8529613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.6836460158228874, "count": 1, "min": 0.6836460158228874, "max": 0.6836460158228874}}}
#
# #metrics {"StartTime": 1617613906.8530395, "EndTime": 1617613906.8530989, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.6713048666715622, "count": 1, "min": 0.6713048666715622, "max": 0.6713048666715622}}}
#
# #metrics {"StartTime": 1617613906.8531878, "EndTime": 1617613906.8532004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.955385855266026, "count": 1, "min": 0.955385855266026, "max": 0.955385855266026}}}
#
# #metrics {"StartTime": 1617613906.8532412, "EndTime": 1617613906.853252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.0353171399661474, "count": 1, "min": 1.0353171399661474, "max": 1.0353171399661474}}}
#
# #metrics {"StartTime": 1617613906.8532903, "EndTime": 1617613906.8532999, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9872397056647709, "count": 1, "min": 0.9872397056647709, "max": 0.9872397056647709}}}
#
# #metrics {"StartTime": 1617613906.853336, "EndTime": 1617613906.8533463, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.090431911604745, "count": 1, "min": 1.090431911604745, "max": 1.090431911604745}}}
#
# #metrics {"StartTime": 1617613906.8533843, "EndTime": 1617613906.8533945, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.2352222204208374, "count": 1, "min": 1.2352222204208374, "max": 1.2352222204208374}}}
#
# #metrics {"StartTime": 1617613906.8535762, "EndTime": 1617613906.8536184, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.1899580912930625, "count": 1, "min": 1.1899580912930625, "max": 1.1899580912930625}}}
#
# #metrics {"StartTime": 1617613906.853666, "EndTime": 1617613906.853678, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.2009898126125336, "count": 1, "min": 1.2009898126125336, "max": 1.2009898126125336}}}
#
# #metrics {"StartTime": 1617613906.8537178, "EndTime": 1617613906.8537273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.2405299374035426, "count": 1, "min": 1.2405299374035426, "max": 1.2405299374035426}}}
#
# [04/05/2021 09:11:46 INFO 140498629949248] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.7377581532512393
# #metrics {"StartTime": 1617613906.921185, "EndTime": 1617613906.9212797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 30.315569709329043, "count": 1, "min": 30.315569709329043, "max": 30.315569709329043}}}
#
# #metrics {"StartTime": 1617613906.921733, "EndTime": 1617613906.921764, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 33.76540599149816, "count": 1, "min": 33.76540599149816, "max": 33.76540599149816}}}
#
# #metrics {"StartTime": 1617613906.9220726, "EndTime": 1617613906.922097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 40.77673639035692, "count": 1, "min": 40.77673639035692, "max": 40.77673639035692}}}
#
# #metrics {"StartTime": 1617613906.9223516, "EndTime": 1617613906.9223738, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 40.080619064031865, "count": 1, "min": 40.080619064031865, "max": 40.080619064031865}}}
#
# #metrics {"StartTime": 1617613906.922622, "EndTime": 1617613906.922644, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 31.699718998927697, "count": 1, "min": 31.699718998927697, "max": 31.699718998927697}}}
#
# #metrics {"StartTime": 1617613906.9228873, "EndTime": 1617613906.9229093, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 24.51398542815564, "count": 1, "min": 24.51398542815564, "max": 24.51398542815564}}}
#
# #metrics {"StartTime": 1617613906.9231513, "EndTime": 1617613906.9231727, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 24.523722330729168, "count": 1, "min": 24.523722330729168, "max": 24.523722330729168}}}
#
# #metrics {"StartTime": 1617613906.923419, "EndTime": 1617613906.9234633, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 34.394051346124385, "count": 1, "min": 34.394051346124385, "max": 34.394051346124385}}}
#
# #metrics {"StartTime": 1617613906.9237273, "EndTime": 1617613906.9237492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 36.218843946269914, "count": 1, "min": 36.218843946269914, "max": 36.218843946269914}}}
#
# #metrics {"StartTime": 1617613906.9239984, "EndTime": 1617613906.9240208, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 28.510434019799327, "count": 1, "min": 28.510434019799327, "max": 28.510434019799327}}}
#
# #metrics {"StartTime": 1617613906.9242978, "EndTime": 1617613906.9243197, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 42.205934412339154, "count": 1, "min": 42.205934412339154, "max": 42.205934412339154}}}
#
# #metrics {"StartTime": 1617613906.9246, "EndTime": 1617613906.9246218, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 38.91234094956342, "count": 1, "min": 38.91234094956342, "max": 38.91234094956342}}}
#
# #metrics {"StartTime": 1617613906.9249055, "EndTime": 1617613906.9249272, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 28.22660079656863, "count": 1, "min": 28.22660079656863, "max": 28.22660079656863}}}
#
# #metrics {"StartTime": 1617613906.9251745, "EndTime": 1617613906.9251962, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 29.8095427868413, "count": 1, "min": 29.8095427868413, "max": 29.8095427868413}}}
#
# #metrics {"StartTime": 1617613906.92544, "EndTime": 1617613906.9254613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 34.92296166513481, "count": 1, "min": 34.92296166513481, "max": 34.92296166513481}}}
#
# #metrics {"StartTime": 1617613906.9257238, "EndTime": 1617613906.9257455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 32.33119111902573, "count": 1, "min": 32.33119111902573, "max": 32.33119111902573}}}
#
# #metrics {"StartTime": 1617613906.925992, "EndTime": 1617613906.9260132, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 33.72746366613052, "count": 1, "min": 33.72746366613052, "max": 33.72746366613052}}}
#
# #metrics {"StartTime": 1617613906.9262936, "EndTime": 1617613906.926346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 39.298743154488356, "count": 1, "min": 39.298743154488356, "max": 39.298743154488356}}}
#
# #metrics {"StartTime": 1617613906.926584, "EndTime": 1617613906.926606, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 32.43510646446079, "count": 1, "min": 32.43510646446079, "max": 32.43510646446079}}}
#
# #metrics {"StartTime": 1617613906.9268374, "EndTime": 1617613906.9268584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 36.47612867168352, "count": 1, "min": 36.47612867168352, "max": 36.47612867168352}}}
#
# #metrics {"StartTime": 1617613906.9270782, "EndTime": 1617613906.927099, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 32.17659206016391, "count": 1, "min": 32.17659206016391, "max": 32.17659206016391}}}
#
# #metrics {"StartTime": 1617613906.9273582, "EndTime": 1617613906.9273794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 22.62556696873085, "count": 1, "min": 22.62556696873085, "max": 22.62556696873085}}}
#
# #metrics {"StartTime": 1617613906.9276457, "EndTime": 1617613906.9276674, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 19.60281671262255, "count": 1, "min": 19.60281671262255, "max": 19.60281671262255}}}
#
# #metrics {"StartTime": 1617613906.9279299, "EndTime": 1617613906.927975, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 24.061935125612745, "count": 1, "min": 24.061935125612745, "max": 24.061935125612745}}}
#
# #metrics {"StartTime": 1617613906.9282215, "EndTime": 1617613906.9282434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 55.75718898399204, "count": 1, "min": 55.75718898399204, "max": 55.75718898399204}}}
#
# #metrics {"StartTime": 1617613906.9284832, "EndTime": 1617613906.928528, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 59.492168351715684, "count": 1, "min": 59.492168351715684, "max": 59.492168351715684}}}
#
# #metrics {"StartTime": 1617613906.928774, "EndTime": 1617613906.9287953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 59.318227730545345, "count": 1, "min": 59.318227730545345, "max": 59.318227730545345}}}
#
# #metrics {"StartTime": 1617613906.9290354, "EndTime": 1617613906.9290574, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 56.267341164981616, "count": 1, "min": 56.267341164981616, "max": 56.267341164981616}}}
#
# #metrics {"StartTime": 1617613906.9293318, "EndTime": 1617613906.9293756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 71.33091945274204, "count": 1, "min": 71.33091945274204, "max": 71.33091945274204}}}
#
# #metrics {"StartTime": 1617613906.9295976, "EndTime": 1617613906.9296184, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 63.78683890548407, "count": 1, "min": 63.78683890548407, "max": 63.78683890548407}}}
#
# #metrics {"StartTime": 1617613906.9298837, "EndTime": 1617613906.9299061, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 59.374775007659316, "count": 1, "min": 59.374775007659316, "max": 59.374775007659316}}}
#
# #metrics {"StartTime": 1617613906.9301426, "EndTime": 1617613906.9301865, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 68.40967155905331, "count": 1, "min": 68.40967155905331, "max": 68.40967155905331}}}
#
# [04/05/2021 09:11:46 INFO 140498629949248] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=30.315569709329043
# [04/05/2021 09:11:46 INFO 140498629949248] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=19.60281671262255
# [04/05/2021 09:11:46 INFO 140498629949248] Epoch 0: Loss improved. Updating best model
# [04/05/2021 09:11:46 INFO 140498629949248] Saving model for epoch: 0
# [04/05/2021 09:11:46 INFO 140498629949248] Saved checkpoint to "/tmp/tmpbzt1qvrb/mx-mod-0000.params"
# [04/05/2021 09:11:46 INFO 140498629949248] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1617613906.532729, "EndTime": 1617613906.9898877, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 942.0, "count": 1, "min": 942, "max": 942}, "Total Batches Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
#
# [04/05/2021 09:11:46 INFO 140498629949248] #throughput_metric: host=algo-1, train throughput=994.7154382978368 records/second
# #metrics {"StartTime": 1617613907.4996872, "EndTime": 1617613907.4997663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.5159480688827378, "count": 1, "min": 0.5159480688827378, "max": 0.5159480688827378}}}
#
# #metrics {"StartTime": 1617613907.5002394, "EndTime": 1617613907.500344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.5501052609511784, "count": 1, "min": 0.5501052609511784, "max": 0.5501052609511784}}}
#
# #metrics {"StartTime": 1617613907.5006344, "EndTime": 1617613907.5007195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.6103851624897548, "count": 1, "min": 0.6103851624897548, "max": 0.6103851624897548}}}
#
# #metrics {"StartTime": 1617613907.50097, "EndTime": 1617613907.5010533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.5918791006718364, "count": 1, "min": 0.5918791006718364, "max": 0.5918791006718364}}}
#
# #metrics {"StartTime": 1617613907.501375, "EndTime": 1617613907.5013971, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.4119564560907228, "count": 1, "min": 0.4119564560907228, "max": 0.4119564560907228}}}
#
# #metrics {"StartTime": 1617613907.5016973, "EndTime": 1617613907.5017817, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.4507268305335726, "count": 1, "min": 0.4507268305335726, "max": 0.4507268305335726}}}
#
# #metrics {"StartTime": 1617613907.5021024, "EndTime": 1617613907.5022054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.3678934563483511, "count": 1, "min": 0.3678934563483511, "max": 0.3678934563483511}}}
#
# #metrics {"StartTime": 1617613907.5024476, "EndTime": 1617613907.5025275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.4104663037828037, "count": 1, "min": 0.4104663037828037, "max": 0.4104663037828037}}}
#
# #metrics {"StartTime": 1617613907.5027747, "EndTime": 1617613907.5028543, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.557077885738441, "count": 1, "min": 0.557077885738441, "max": 0.557077885738441}}}
#
# #metrics {"StartTime": 1617613907.50311, "EndTime": 1617613907.5031967, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.4595038928091526, "count": 1, "min": 0.4595038928091526, "max": 0.4595038928091526}}}
#
# #metrics {"StartTime": 1617613907.5034552, "EndTime": 1617613907.5035455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.5946509795529502, "count": 1, "min": 0.5946509795529502, "max": 0.5946509795529502}}}
#
# #metrics {"StartTime": 1617613907.5038276, "EndTime": 1617613907.503916, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.6298624788011823, "count": 1, "min": 0.6298624788011823, "max": 0.6298624788011823}}}
#
# #metrics {"StartTime": 1617613907.5041716, "EndTime": 1617613907.5042598, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.4452848434448242, "count": 1, "min": 0.4452848434448242, "max": 0.4452848434448242}}}
#
# #metrics {"StartTime": 1617613907.5045218, "EndTime": 1617613907.5046096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.39333535730838776, "count": 1, "min": 0.39333535730838776, "max": 0.39333535730838776}}}
#
# #metrics {"StartTime": 1617613907.5048716, "EndTime": 1617613907.50496, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.40846793353557587, "count": 1, "min": 0.40846793353557587, "max": 0.40846793353557587}}}
#
# #metrics {"StartTime": 1617613907.5052457, "EndTime": 1617613907.5053372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.4336365503924234, "count": 1, "min": 0.4336365503924234, "max": 0.4336365503924234}}}
#
# #metrics {"StartTime": 1617613907.5055966, "EndTime": 1617613907.5056884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.5265307426452637, "count": 1, "min": 0.5265307426452637, "max": 0.5265307426452637}}}
#
# #metrics {"StartTime": 1617613907.5059566, "EndTime": 1617613907.5060484, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.5931071149451392, "count": 1, "min": 0.5931071149451392, "max": 0.5931071149451392}}}
#
# #metrics {"StartTime": 1617613907.506324, "EndTime": 1617613907.5064151, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.5194542386702129, "count": 1, "min": 0.5194542386702129, "max": 0.5194542386702129}}}
#
# #metrics {"StartTime": 1617613907.5066767, "EndTime": 1617613907.5067663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.5669495878475053, "count": 1, "min": 0.5669495878475053, "max": 0.5669495878475053}}}
#
# #metrics {"StartTime": 1617613907.5070355, "EndTime": 1617613907.507124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.5002822365079608, "count": 1, "min": 0.5002822365079608, "max": 0.5002822365079608}}}
#
# #metrics {"StartTime": 1617613907.5073876, "EndTime": 1617613907.5074766, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.47502086258360315, "count": 1, "min": 0.47502086258360315, "max": 0.47502086258360315}}}
#
# #metrics {"StartTime": 1617613907.5077846, "EndTime": 1617613907.507876, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.47657493714775356, "count": 1, "min": 0.47657493714775356, "max": 0.47657493714775356}}}
#
# #metrics {"StartTime": 1617613907.5081382, "EndTime": 1617613907.508227, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.4856811133878572, "count": 1, "min": 0.4856811133878572, "max": 0.4856811133878572}}}
#
# #metrics {"StartTime": 1617613907.50851, "EndTime": 1617613907.5086021, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9542617265667234, "count": 1, "min": 0.9542617265667234, "max": 0.9542617265667234}}}
#
# #metrics {"StartTime": 1617613907.5088885, "EndTime": 1617613907.5089784, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9430061812911715, "count": 1, "min": 0.9430061812911715, "max": 0.9430061812911715}}}
#
# #metrics {"StartTime": 1617613907.5092368, "EndTime": 1617613907.5093267, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9516104821647916, "count": 1, "min": 0.9516104821647916, "max": 0.9516104821647916}}}
#
# #metrics {"StartTime": 1617613907.5095856, "EndTime": 1617613907.5096753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9182526256356921, "count": 1, "min": 0.9182526256356921, "max": 0.9182526256356921}}}
#
# #metrics {"StartTime": 1617613907.5099292, "EndTime": 1617613907.5100393, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.9664367054189954, "count": 1, "min": 0.9664367054189954, "max": 0.9664367054189954}}}
#
# #metrics {"StartTime": 1617613907.510306, "EndTime": 1617613907.510394, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9548059489045825, "count": 1, "min": 0.9548059489045825, "max": 0.9548059489045825}}}
#
# #metrics {"StartTime": 1617613907.510662, "EndTime": 1617613907.5107527, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9545830892665046, "count": 1, "min": 0.9545830892665046, "max": 0.9545830892665046}}}
#
# #metrics {"StartTime": 1617613907.5110152, "EndTime": 1617613907.511104, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9647682905197144, "count": 1, "min": 0.9647682905197144, "max": 0.9647682905197144}}}
#
# [04/05/2021 09:11:47 INFO 140498629949248] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.5159480688827378
# #metrics {"StartTime": 1617613907.586665, "EndTime": 1617613907.5867467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 25.06375720454197, "count": 1, "min": 25.06375720454197, "max": 25.06375720454197}}}
#
# #metrics {"StartTime": 1617613907.5869517, "EndTime": 1617613907.5871499, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 27.98169184666054, "count": 1, "min": 27.98169184666054, "max": 27.98169184666054}}}
#
# #metrics {"StartTime": 1617613907.5874543, "EndTime": 1617613907.587547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 32.92351277669271, "count": 1, "min": 32.92351277669271, "max": 32.92351277669271}}}
#
# #metrics {"StartTime": 1617613907.587858, "EndTime": 1617613907.5879502, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 31.955702837775736, "count": 1, "min": 31.955702837775736, "max": 31.955702837775736}}}
#
# #metrics {"StartTime": 1617613907.5882158, "EndTime": 1617613907.5883062, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 23.801806879978553, "count": 1, "min": 23.801806879978553, "max": 23.801806879978553}}}
#
# #metrics {"StartTime": 1617613907.5885718, "EndTime": 1617613907.5886624, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 27.032402487362134, "count": 1, "min": 27.032402487362134, "max": 27.032402487362134}}}
#
# #metrics {"StartTime": 1617613907.5889163, "EndTime": 1617613907.5890012, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 18.046345430261947, "count": 1, "min": 18.046345430261947, "max": 18.046345430261947}}}
#
# #metrics {"StartTime": 1617613907.5892692, "EndTime": 1617613907.5893567, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 28.026753743489582, "count": 1, "min": 28.026753743489582, "max": 28.026753743489582}}}
#
# #metrics {"StartTime": 1617613907.58964, "EndTime": 1617613907.5897346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 29.163744159773284, "count": 1, "min": 29.163744159773284, "max": 29.163744159773284}}}
#
# #metrics {"StartTime": 1617613907.589998, "EndTime": 1617613907.590088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 23.167307535807293, "count": 1, "min": 23.167307535807293, "max": 23.167307535807293}}}
#
# #metrics {"StartTime": 1617613907.590354, "EndTime": 1617613907.5904455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 31.58735387465533, "count": 1, "min": 31.58735387465533, "max": 31.58735387465533}}}
#
# #metrics {"StartTime": 1617613907.5907211, "EndTime": 1617613907.5908108, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 31.70578182444853, "count": 1, "min": 31.70578182444853, "max": 31.70578182444853}}}
#
# #metrics {"StartTime": 1617613907.5910716, "EndTime": 1617613907.5911615, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 28.591149423636644, "count": 1, "min": 28.591149423636644, "max": 28.591149423636644}}}
#
# #metrics {"StartTime": 1617613907.5914204, "EndTime": 1617613907.5915072, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 18.902648327397365, "count": 1, "min": 18.902648327397365, "max": 18.902648327397365}}}
#
# #metrics {"StartTime": 1617613907.5917804, "EndTime": 1617613907.5918663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 26.101415297564337, "count": 1, "min": 26.101415297564337, "max": 26.101415297564337}}}
#
# #metrics {"StartTime": 1617613907.592133, "EndTime": 1617613907.5922189, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 30.510671578201592, "count": 1, "min": 30.510671578201592, "max": 30.510671578201592}}}
#
# #metrics {"StartTime": 1617613907.5925353, "EndTime": 1617613907.5925565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 27.768508013556986, "count": 1, "min": 27.768508013556986, "max": 27.768508013556986}}}
#
# #metrics {"StartTime": 1617613907.592786, "EndTime": 1617613907.5928705, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 30.992431042241115, "count": 1, "min": 30.992431042241115, "max": 30.992431042241115}}}
#
# #metrics {"StartTime": 1617613907.5931218, "EndTime": 1617613907.593205, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 26.77027204924939, "count": 1, "min": 26.77027204924939, "max": 26.77027204924939}}}
#
# #metrics {"StartTime": 1617613907.5934572, "EndTime": 1617613907.5935385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 29.092355167164524, "count": 1, "min": 29.092355167164524, "max": 29.092355167164524}}}
#
# #metrics {"StartTime": 1617613907.5937684, "EndTime": 1617613907.593854, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 15.700639911726409, "count": 1, "min": 15.700639911726409, "max": 15.700639911726409}}}
#
# #metrics {"StartTime": 1617613907.5941045, "EndTime": 1617613907.5941918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 16.520503324620865, "count": 1, "min": 16.520503324620865, "max": 16.520503324620865}}}
#
# #metrics {"StartTime": 1617613907.5944417, "EndTime": 1617613907.5945303, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 16.468407724417894, "count": 1, "min": 16.468407724417894, "max": 16.468407724417894}}}
#
# #metrics {"StartTime": 1617613907.5947986, "EndTime": 1617613907.5948863, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 15.495150696997548, "count": 1, "min": 15.495150696997548, "max": 15.495150696997548}}}
#
# #metrics {"StartTime": 1617613907.5951233, "EndTime": 1617613907.5952098, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 59.39354152305454, "count": 1, "min": 59.39354152305454, "max": 59.39354152305454}}}
#
# #metrics {"StartTime": 1617613907.5954578, "EndTime": 1617613907.5955405, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 56.115729836856616, "count": 1, "min": 56.115729836856616, "max": 56.115729836856616}}}
#
# #metrics {"StartTime": 1617613907.595811, "EndTime": 1617613907.595902, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 57.351294424019606, "count": 1, "min": 57.351294424019606, "max": 57.351294424019606}}}
#
# #metrics {"StartTime": 1617613907.5960193, "EndTime": 1617613907.5961566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 56.74484432444853, "count": 1, "min": 56.74484432444853, "max": 56.74484432444853}}}
#
# #metrics {"StartTime": 1617613907.5962713, "EndTime": 1617613907.5964096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 58.63835233800552, "count": 1, "min": 58.63835233800552, "max": 58.63835233800552}}}
#
# #metrics {"StartTime": 1617613907.5965292, "EndTime": 1617613907.5966632, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 56.394081265318626, "count": 1, "min": 56.394081265318626, "max": 56.394081265318626}}}
#
# ...
#
# #metrics {"StartTime": 1617613913.53358, "EndTime": 1617613913.5335903, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.9756010941096714, "count": 1, "min": 0.9756010941096714, "max": 0.9756010941096714}}}
#
# #metrics {"StartTime": 1617613913.5336292, "EndTime": 1617613913.5336397, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9619745974029813, "count": 1, "min": 0.9619745974029813, "max": 0.9619745974029813}}}
#
# #metrics {"StartTime": 1617613913.533677, "EndTime": 1617613913.533704, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9756145903042385, "count": 1, "min": 0.9756145903042385, "max": 0.9756145903042385}}}
#
# #metrics {"StartTime": 1617613913.5337458, "EndTime": 1617613913.5337744, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9644063051257815, "count": 1, "min": 0.9644063051257815, "max": 0.9644063051257815}}}
#
# [04/05/2021 09:11:53 INFO 140498629949248] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.2742882344339575
# #metrics {"StartTime": 1617613913.5857575, "EndTime": 1617613913.585808, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 15.225217931410846, "count": 1, "min": 15.225217931410846, "max": 15.225217931410846}}}
#
# #metrics {"StartTime": 1617613913.5858738, "EndTime": 1617613913.5859096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 15.595155603745404, "count": 1, "min": 15.595155603745404, "max": 15.595155603745404}}}
#
# #metrics {"StartTime": 1617613913.5859556, "EndTime": 1617613913.5859864, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 15.27371155981924, "count": 1, "min": 15.27371155981924, "max": 15.27371155981924}}}
#
# #metrics {"StartTime": 1617613913.5860322, "EndTime": 1617613913.5860434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 15.973947562423406, "count": 1, "min": 15.973947562423406, "max": 15.973947562423406}}}
#
# #metrics {"StartTime": 1617613913.5860806, "EndTime": 1617613913.5860896, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 16.274225571576288, "count": 1, "min": 16.274225571576288, "max": 16.274225571576288}}}
#
# #metrics {"StartTime": 1617613913.5861263, "EndTime": 1617613913.5861359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 16.15048277611826, "count": 1, "min": 16.15048277611826, "max": 16.15048277611826}}}
#
# #metrics {"StartTime": 1617613913.5861704, "EndTime": 1617613913.5861795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 15.98442466586244, "count": 1, "min": 15.98442466586244, "max": 15.98442466586244}}}
#
# #metrics {"StartTime": 1617613913.5862374, "EndTime": 1617613913.5862498, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 15.809560738357844, "count": 1, "min": 15.809560738357844, "max": 15.809560738357844}}}
#
# #metrics {"StartTime": 1617613913.5863144, "EndTime": 1617613913.5863266, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 14.84016867244945, "count": 1, "min": 14.84016867244945, "max": 14.84016867244945}}}
#
# #metrics {"StartTime": 1617613913.5863688, "EndTime": 1617613913.5863793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 15.457574582567402, "count": 1, "min": 15.457574582567402, "max": 15.457574582567402}}}
#
# #metrics {"StartTime": 1617613913.586438, "EndTime": 1617613913.5864506, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 15.49526917700674, "count": 1, "min": 15.49526917700674, "max": 15.49526917700674}}}
#
# #metrics {"StartTime": 1617613913.5865102, "EndTime": 1617613913.5865223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 15.642092835669423, "count": 1, "min": 15.642092835669423, "max": 15.642092835669423}}}
#
# #metrics {"StartTime": 1617613913.5865777, "EndTime": 1617613913.5865898, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 18.547529631969976, "count": 1, "min": 18.547529631969976, "max": 18.547529631969976}}}
#
# #metrics {"StartTime": 1617613913.5866518, "EndTime": 1617613913.5866642, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 15.636513504327512, "count": 1, "min": 15.636513504327512, "max": 15.636513504327512}}}
#
# #metrics {"StartTime": 1617613913.5867062, "EndTime": 1617613913.586717, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 16.302373549517462, "count": 1, "min": 16.302373549517462, "max": 16.302373549517462}}}
#
# #metrics {"StartTime": 1617613913.5867748, "EndTime": 1617613913.586788, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 15.844754686542586, "count": 1, "min": 15.844754686542586, "max": 15.844754686542586}}}
#
# #metrics {"StartTime": 1617613913.5868468, "EndTime": 1617613913.586859, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 19.782718434053308, "count": 1, "min": 19.782718434053308, "max": 19.782718434053308}}}
#
# #metrics {"StartTime": 1617613913.5868955, "EndTime": 1617613913.586921, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 19.823299033969057, "count": 1, "min": 19.823299033969057, "max": 19.823299033969057}}}
#
# #metrics {"StartTime": 1617613913.5869634, "EndTime": 1617613913.586993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 19.784983915441178, "count": 1, "min": 19.784983915441178, "max": 19.784983915441178}}}
#
# #metrics {"StartTime": 1617613913.587038, "EndTime": 1617613913.5870492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 19.811009425742952, "count": 1, "min": 19.811009425742952, "max": 19.811009425742952}}}
#
# #metrics {"StartTime": 1617613913.587088, "EndTime": 1617613913.5870988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 18.72761894674862, "count": 1, "min": 18.72761894674862, "max": 18.72761894674862}}}
#
# #metrics {"StartTime": 1617613913.5873098, "EndTime": 1617613913.5873342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 18.90918806487439, "count": 1, "min": 18.90918806487439, "max": 18.90918806487439}}}
#
# #metrics {"StartTime": 1617613913.5874128, "EndTime": 1617613913.587426, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 18.701621261297486, "count": 1, "min": 18.701621261297486, "max": 18.701621261297486}}}
#
# #metrics {"StartTime": 1617613913.587481, "EndTime": 1617613913.587494, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 18.880876129748774, "count": 1, "min": 18.880876129748774, "max": 18.880876129748774}}}
#
# #metrics {"StartTime": 1617613913.587556, "EndTime": 1617613913.5875685, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 58.3131378772212, "count": 1, "min": 58.3131378772212, "max": 58.3131378772212}}}
#
# #metrics {"StartTime": 1617613913.5876331, "EndTime": 1617613913.5876443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 58.37051690793505, "count": 1, "min": 58.37051690793505, "max": 58.37051690793505}}}
#
# #metrics {"StartTime": 1617613913.5877092, "EndTime": 1617613913.587721, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 58.057838589537376, "count": 1, "min": 58.057838589537376, "max": 58.057838589537376}}}
#
# #metrics {"StartTime": 1617613913.5877764, "EndTime": 1617613913.5877912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 58.55697332643995, "count": 1, "min": 58.55697332643995, "max": 58.55697332643995}}}
#
# #metrics {"StartTime": 1617613913.5878482, "EndTime": 1617613913.5878608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 55.45585961435356, "count": 1, "min": 55.45585961435356, "max": 55.45585961435356}}}
#
# #metrics {"StartTime": 1617613913.5879169, "EndTime": 1617613913.5879292, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 56.75125062231924, "count": 1, "min": 56.75125062231924, "max": 56.75125062231924}}}
#
# #metrics {"StartTime": 1617613913.5879917, "EndTime": 1617613913.5880036, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 55.06959443933823, "count": 1, "min": 55.06959443933823, "max": 55.06959443933823}}}
#
# #metrics {"StartTime": 1617613913.5880601, "EndTime": 1617613913.5880737, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 56.52135632084865, "count": 1, "min": 56.52135632084865, "max": 56.52135632084865}}}
#
# [04/05/2021 09:11:53 INFO 140498629949248] #quality_metric: host=algo-1, epoch=14, validation mse_objective <loss>=15.225217931410846
# [04/05/2021 09:11:53 INFO 140498629949248] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=14.84016867244945
# [04/05/2021 09:11:53 INFO 140498629949248] Saving model for epoch: 14
# [04/05/2021 09:11:53 INFO 140498629949248] Saved checkpoint to "/tmp/tmpoom2fakb/mx-mod-0000.params"
# [04/05/2021 09:11:53 INFO 140498629949248] Early stop condition met. Stopping training.
# [04/05/2021 09:11:53 INFO 140498629949248] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1617613913.1322813, "EndTime": 1617613913.5936105, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 7312.0, "count": 1, "min": 7312, "max": 7312}, "Total Batches Seen": {"sum": 241.0, "count": 1, "min": 241, "max": 241}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
#
# [04/05/2021 09:11:53 INFO 140498629949248] #throughput_metric: host=algo-1, train throughput=985.9472238453118 records/second
# [04/05/2021 09:11:53 WARNING 140498629949248] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/05/2021 09:11:53 WARNING 140498629949248] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/05/2021 09:11:53 INFO 140498629949248] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=14.84016867244945
# [04/05/2021 09:11:53 INFO 140498629949248] #validation_score (algo-1) : ('mse_objective', 14.64364564185049)
# [04/05/2021 09:11:53 INFO 140498629949248] #validation_score (algo-1) : ('mse', 14.64364564185049)
# [04/05/2021 09:11:53 INFO 140498629949248] #validation_score (algo-1) : ('absolute_loss', 3.0190790213790595)
# [04/05/2021 09:11:53 INFO 140498629949248] #quality_metric: host=algo-1, validation mse_objective <loss>=14.64364564185049
# [04/05/2021 09:11:53 INFO 140498629949248] #quality_metric: host=algo-1, validation mse <loss>=14.64364564185049
# [04/05/2021 09:11:53 INFO 140498629949248] #quality_metric: host=algo-1, validation absolute_loss <loss>=3.0190790213790595
# [04/05/2021 09:11:53 INFO 140498629949248] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 0.01, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [04/05/2021 09:11:53 INFO 140498629949248] Saved checkpoint to "/tmp/tmpolr_z5xy/mx-mod-0000.params"
# [04/05/2021 09:11:53 INFO 140498629949248] Test data is not provided.
# #metrics {"StartTime": 1617613906.2862215, "EndTime": 1617613913.6654634, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 234.544038772583, "count": 1, "min": 234.544038772583, "max": 234.544038772583}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 11.347532272338867, "count": 16, "min": 0.1964569091796875, "max": 1.5261173248291016}, "update.time": {"sum": 6954.875946044922, "count": 15, "min": 351.79686546325684, "max": 683.445930480957}, "finalize.time": {"sum": 63.49301338195801, "count": 1, "min": 63.49301338195801, "max": 63.49301338195801}, "setuptime": {"sum": 28.378725051879883, "count": 1, "min": 28.378725051879883, "max": 28.378725051879883}, "totaltime": {"sum": 7603.822708129883, "count": 1, "min": 7603.822708129883, "max": 7603.822708129883}}}
#
#
# 2021-04-05 09:12:06 Uploading - Uploading generated training model
# 2021-04-05 09:12:06 Completed - Training job completed
# Training seconds: 68
# Billable seconds: 68

# %%
sagemaker.get_execution_role()
# Out:
# Couldn't call 'get_role' to get Role ARN from role name AmazonSageMaker-ExecutionRole-20210403T113990 to get Role path.
# Assuming role was created in SageMaker AWS console, as the name contains `AmazonSageMaker-ExecutionRole`. Defaulting to Role ARN with service-role in path. If this Role ARN is incorrect, please add IAM read permissions to your role or supply the Role Arn directly.
# 'arn:aws:iam::076084266064:role/service-role/AmazonSageMaker-ExecutionRole-20210403T113990'
